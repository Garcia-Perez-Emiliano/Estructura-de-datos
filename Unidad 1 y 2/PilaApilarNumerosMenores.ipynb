# %%
class Pila:
    def __init__(self):
        self.items=[]

    def apilar(self,x):
        self.items.append(x)

    def despilar(self):
        try:
            return self.items.pop()
        except IndexError:
            raise ValueError("La pila esta vacia")

    def es_vacia(self):
        return self.items==[]

    def imprimir(self):
        print("*********")
        reversed_items = (reversed(self.items))
        for item in reversed_items:
            print(str(item))

def menu():
    p1 = Pila()
    op=0
    while op!=4:
        print("*********")
        print("1. Apilar numeros\n2. Imprimir\n3. Borrar\n4. Salir")
        op=int(input("->"))
        if op==1:
            apilar1(p1)
        elif op==2:
            impri(p1)
        elif op==3:
            borrar(p1)

def apilar1(pila):
    if len(pila.items)==0:
        print("Ingresa un nuevo numero")
        n=int(input("->"))
        pila.apilar(n)
        salir=False
        while salir==False:
            print("Ingresa un nuevo numero")
            n = int(input("->"))
            if n <= pila.items[len(pila.items)-1]:
                pila.apilar(n)
            else:
                print("No se puede ingresar un nuevo numero")
                salir=True
    else:
        salir = False
        while salir == False:
            print("Ingresa un nuevo numero")
            n = int(input("->"))
            if n <= pila.items[len(pila.items)-1]:
                pila.apilar(n)
            else:
                print("No se puede ingresar un nuevo numero")
                salir = True

def impri(pila):
    pila.imprimir()

def borrar(pila):
    for i in range (0,len(pila.items)):
        pila.despilar()

menu()
# Out:
# *********
# 1. Apilar numeros
# 2. Imprimir
# 3. Borrar
# 4. Salir
# ->1
# Ingresa un nuevo numero
# ->8
# Ingresa un nuevo numero
# ->7
# Ingresa un nuevo numero
# ->6
# Ingresa un nuevo numero
# ->6
# Ingresa un nuevo numero
# ->8
# No se puede ingresar un nuevo numero
# *********
# 1. Apilar numeros
# 2. Imprimir
# 3. Borrar
# 4. Salir
# ->2
# *********
# 6
# 6
# 7
# 8
# *********
# 1. Apilar numeros
# 2. Imprimir
# 3. Borrar
# 4. Salir
# ->3
# *********
# 1. Apilar numeros
# 2. Imprimir
# 3. Borrar
# 4. Salir
# ->2
# *********
# *********
# 1. Apilar numeros
# 2. Imprimir
# 3. Borrar
# 4. Salir
# ->4
